# %% [markdown]
# # Exploracao inicial do Aurora Regime AI
#
# Notebook inicial para validar ambiente, estrutura do projeto e proximos passos da pesquisa quantitativa.

# %%
from aurora.config import get_settings

settings = get_settings()
settings
